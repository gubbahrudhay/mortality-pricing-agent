# %% [markdown]
# # Data Exploration Notebook
# This notebook explores the baseline mortality data loaded from the raw table.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/mortality_table.csv')
print(f"Mortality table loaded: {df.shape[0]} ages.")
df.head()
